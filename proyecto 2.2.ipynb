# %% [markdown]
# # Módulo 2 Tarea 2: Control de flujos, Condicionales y Bucles
# Resolución de los 10 ejercicios del Tema 2 sobre condicionales, bucles, acumuladores y manejo de colecciones en Python.

# %% [markdown]
# # Ejercicio 1: Orden de los números
